# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_excel('County_Statistics_with_Temp.xlsx')

# %%
df.shape
# Out:
# (58, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   County                           58 non-null     object
#  1   Emergency Visits / 100000        43 non-null     float64
#  2   Hospitalizations / 100000        19 non-null     float64
#  3   Energy Burden % of Income        58 non-null     object
#  4   Imperviousness                   58 non-null     object
#  5   Park within 1/2 Mile             58 non-null     object
#  6   Hospital Beds / 10000            58 non-null     object
#  7   Housing Built before 1980        58 non-null     object
#  8   Housing Insecurity               58 non-null     object
#  9   Lack of Reliable Transportation  58 non-null     object
#  10  % w/o Internet                   58 non-null     object
#  11  Utility Services Threat          58 non-null     object
#  12  July max temp (F)                58 non-null     float64
#  13  August max temp (F)              58 non-null     float64
#  14  July CDD                         58 non-null     int64
#  15  August CDD                       58 non-null     int64
# dtypes: float64(4), int64(2), object(10)
# memory usage: 7.4+ KB

# %%
df.describe()
# Out:
#        Emergency Visits / 100000  Hospitalizations / 100000  \
# count                  43.000000                  19.000000
# mean                   23.237907                   3.887895
# std                    19.456523                   3.226049
# min                     2.890000                   0.680000
# 25%                     9.225000                   1.350000
# 50%                    19.750000                   3.700000
# 75%                    30.060000                   4.210000
# max                   115.940000                  11.650000
#
#        July max temp (F)  August max temp (F)     July CDD  August CDD
# count          58.000000            58.000000    58.000000   58.000000
# mean           90.553448            87.729310   332.241379  283.258621
# std             7.614050             6.689977   200.907180  170.805682
# min            70.200000            72.400000    10.000000   20.000000
# 25%            86.000000            83.725000   192.000000  169.750000
# 50%            91.250000            87.700000   315.000000  259.000000
# 75%            95.725000            92.350000   445.250000  408.250000
# max           112.100000           107.200000  1010.000000  903.000000

# %%
df[['Emergency Visits / 100000', 'Hospitalizations / 100000']].describe()
# Out:
#        Emergency Visits / 100000  Hospitalizations / 100000
# count                  43.000000                  19.000000
# mean                   23.237907                   3.887895
# std                    19.456523                   3.226049
# min                     2.890000                   0.680000
# 25%                     9.225000                   1.350000
# 50%                    19.750000                   3.700000
# 75%                    30.060000                   4.210000
# max                   115.940000                  11.650000

# %%
df[['Emergency Visits / 100000', 'Hospitalizations / 100000']].info()
df[['Emergency Visits / 100000', 'Hospitalizations / 100000']].describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Emergency Visits / 100000  43 non-null     float64
#  1   Hospitalizations / 100000  19 non-null     float64
# dtypes: float64(2)
# memory usage: 1.0 KB
#        Emergency Visits / 100000  Hospitalizations / 100000
# count                  43.000000                  19.000000
# mean                   23.237907                   3.887895
# std                    19.456523                   3.226049
# min                     2.890000                   0.680000
# 25%                     9.225000                   1.350000
# 50%                    19.750000                   3.700000
# 75%                    30.060000                   4.210000
# max                   115.940000                  11.650000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Emergency Visits
sns.histplot(df['Emergency Visits / 100000'], bins=15, kde=True)
plt.title('Distribution of Emergency Visits per 100,000 (All Counties)')
plt.xlabel('Emergency Visits per 100,000')
plt.ylabel('Number of Counties')
plt.show()

# Hospitalizations
sns.histplot(df['Hospitalizations / 100000'], bins=15, kde=True, color='orange')
plt.title('Distribution of Hospitalizations per 100,000 (All Counties)')
plt.xlabel('Hospitalizations per 100,000')
plt.ylabel('Number of Counties')
plt.show()
#Notes: A few counties have high ER visit and that corresponds to high heat counties like Imperial County
# Same with hospitalization

# %%
df_sorted = df.sort_values('Emergency Visits / 100000', ascending=False)
df_sorted[['County', 'Emergency Visits / 100000', 'Hospitalizations / 100000']].head(10)
#why does Imperial county so different? Wierd.
# Out:
#         County  Emergency Visits / 100000  Hospitalizations / 100000
# 12    Imperial                     115.94                      11.65
# 57        Yuba                      51.70                        NaN
# 10       Glenn                      47.49                        NaN
# 44      Shasta                      45.59                       7.96
# 3        Butte                      43.53                      11.34
# 50      Sutter                      42.13                        NaN
# 56        Yolo                      35.67                        NaN
# 14        Kern                      33.46                       4.26
# 54    Tuolumne                      33.28                        NaN
# 49  Stanislaus                      31.31                       3.75

# %%
sns.scatterplot(
    data=df,
    x='July max temp (F)',
    y='Emergency Visits / 100000'
)
plt.title('Emergency Visits vs July Max Temperature')
plt.show()
# Perfect! More hot means more ER visit. Are the dates same? If yes, then this is a trend.

# %%
sns.scatterplot(
    data=df,
    x='August max temp (F)',
    y='Emergency Visits / 100000'
)
plt.title('Emergency Visits vs August Max Temperature')
plt.show()
#same trend for August

# %%
sns.scatterplot(
    data=df,
    x='Emergency Visits / 100000',
    y='Hospitalizations / 100000'
)
plt.title('Emergency Visits vs Hospitalizations per 100,000')
plt.show()
#Most people that go into the ER are hospitalized?

# %%
df.sort_values('Emergency Visits / 100000', ascending=False).head(5)
# Out:
#       County  Emergency Visits / 100000  Hospitalizations / 100000  \
# 12  Imperial                     115.94                      11.65
# 57      Yuba                      51.70                        NaN
# 10     Glenn                      47.49                        NaN
# 44    Shasta                      45.59                       7.96
# 3      Butte                      43.53                      11.34
#
#    Energy Burden % of Income Imperviousness Park within 1/2 Mile  \
# 12                      3.3%           1.2%                64.0%
# 57                      3.2%           1.5%                56.0%
# 10                      3.6%           1.0%                37.8%
# 44                      3.6%           0.9%                58.5%
# 3                       3.2%           2.0%                62.6%
#
#    Hospital Beds / 10000 Housing Built before 1980 Housing Insecurity  \
# 12                 14.93                    38.25%              24.3%
# 57                 26.97                    47.58%              16.4%
# 10                 16.27                    58.14%              18.3%
# 44                 32.44                    48.42%              12.2%
# 3                  22.42                    52.83%              12.2%
#
#    Lack of Reliable Transportation % w/o Internet Utility Services Threat  \
# 12                           15.6%          10.2%                   12.6%
# 57                           11.0%           8.8%                    8.9%
# 10                           12.1%          12.8%                    9.5%
# 44                            8.7%           8.7%                    6.8%
# 3                             8.5%           7.9%                    6.9%
#
#     July max temp (F)  August max temp (F)  July CDD  August CDD
# 12              112.1                107.2      1010         903
# 57               96.7                 93.2       472         410
# 10               95.5                 94.0       467         443
# 44               94.0                 90.2       382         303
# 3                95.9                 93.1       456         403

# %%
df[['Emergency Visits / 100000', 'August max temp (F)']].corr()
# Out:
#                            Emergency Visits / 100000  August max temp (F)
# Emergency Visits / 100000                   1.000000             0.687191
# August max temp (F)                         0.687191             1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lmplot(data=df, x='August max temp (F)', y='Emergency Visits / 100000')
plt.title('Emergency Visits vs August Max Temperature (Trend Line)')
plt.show()
#tried adding trend line but not necessary
